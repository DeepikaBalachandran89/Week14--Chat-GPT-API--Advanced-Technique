# %%
# !pip install python-dotenv

# %%
# !pip install google-generativeai
# Out:
# ...
#    ---------------------------------------- 0.0/164.0 kB ? eta -:--:--
#    ----------------- ---------------------- 71.7/164.0 kB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  163.8/164.0 kB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 164.0/164.0 kB 1.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/725.4 kB ? eta -:--:--
#    ----- ---------------------------------- 92.2/725.4 kB 2.6 MB/s eta 0:00:01
#    ----------- ---------------------------- 204.8/725.4 kB 2.5 MB/s eta 0:00:01
#    ------------------ --------------------- 327.7/725.4 kB 2.5 MB/s eta 0:00:01
#    ------------------------- -------------- 471.0/725.4 kB 2.7 MB/s eta 0:00:01
#    -------------------------------- ------- 583.7/725.4 kB 2.6 MB/s eta 0:00:01
#    ------------------------------------ --- 655.4/725.4 kB 2.4 MB/s eta 0:00:01
#    ---------------------------------------  716.8/725.4 kB 2.3 MB/s eta 0:00:01
# ...

# %%
import google.generativeai as genai

# Directly configure API key (replace 'API' with your actual API key)
genai.configure(api_key="AIzaSyBGro6QlXWXmo1-4hoB7ekN6pNHhPvYrgc")

# Use the generative model for text-only response
model = genai.GenerativeModel(model_name="gemini-1.5-flash")
response = model.generate_content(["Describe a sun."])

# Print the generated text response
print(response.text)
description = response.text
# Out:
# The sun, a radiant giant, hangs in the vast expanse of space, a constant source of light and heat for our planet. A swirling ball of incandescent gas, it's a nuclear furnace, where hydrogen atoms fuse to create helium, releasing unimaginable amounts of energy.
#
# **Here's a more detailed description:**
#
# * **Appearance:** From Earth, the sun appears as a brilliant yellow sphere, though it actually emits all colors of the rainbow.
# * **Size:**  The sun is a colossal star, with a diameter roughly 109 times that of Earth.
# * **Temperature:** Its surface temperature reaches a scorching 10,000 degrees Fahrenheit, while its core burns at a staggering 27 million degrees Fahrenheit.
# * **Composition:** Composed primarily of hydrogen and helium, with trace amounts of other elements.
# * **Energy:** The sun's energy, reaching Earth as sunlight, fuels life and drives weather patterns.
# ...

# %%
# this is a INSTRUCTION BASED MODEL

# THIS IS A SMALL PROGRAM USING OF API,INSTRUCTION GIVING,THEN OUTPUT HOW TO SEE----> ( CODING)
